# %%
import cv2
import numpy as np
from sklearn import svm
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
features = []
labels = []

# %%
# 用于决定采集的数据标签
is_positive = False

# %%
# 鼠标回调函数
def on_mouse(event, x, y, flags, param):
    global features, labels, is_positive

    if event == cv2.EVENT_LBUTTONDOWN:
        color = img[y, x] # 虽然是img[y, x], 但是返回的是BGR三个通道的数值

        # 根据标签决定是正样本还是负样本，标签在主函数中根据键入来更改
        if is_positive:
            labels.append(1)
        else:
            labels.append(0)

        features.append(color)
        print(f'Collected color: {color} at position: {(x, y)} with label: {labels[-1]}')

# %%
cv2.namedWindow('image')
cv2.setMouseCallback("image", on_mouse)

img = cv2.imread('./data/0618.png')

while True:
    cv2.imshow('image', img)

    key = cv2.waitKey(1) & 0xFF

    if key == ord('y'):
        print(f"Collecting positive samples. Press 'n' to switch, 'Esc' to stop.")
        is_positive = True
    elif key == ord('n'):
        print(f"Collecting positive samples. Press 'y' to switch, 'Esc' to stop.")
        is_positive = False
    elif key == 27:
        print("Stopping data collection.")
        break

cv2.destroyAllWindows()
# Out:
# Collecting positive samples. Press 'n' to switch, 'Esc' to stop.
# Collected color: [204 196 187] at position: (375, 47) with label: 1
# Collected color: [216 205 195] at position: (359, 50) with label: 1
# Collected color: [190 187 183] at position: (341, 56) with label: 1
# Collected color: [209 202 194] at position: (323, 62) with label: 1
# Collected color: [214 206 202] at position: (309, 65) with label: 1
# Collected color: [244 236 237] at position: (293, 69) with label: 1
# Collected color: [250 244 247] at position: (265, 80) with label: 1
# Collected color: [245 243 247] at position: (227, 90) with label: 1
# Collected color: [233 227 229] at position: (177, 109) with label: 1
# Collected color: [199 199 204] at position: (112, 128) with label: 1
# Collected color: [183 180 180] at position: (63, 142) with label: 1
# Collected color: [178 178 184] at position: (32, 157) with label: 1
# Collected color: [178 177 183] at position: (9, 173) with label: 1
# Collected color: [184 181 183] at position: (15, 208) with label: 1
# Collected color: [169 168 177] at position: (61, 224) with label: 1
# Collected color: [162 165 173] at position: (222, 231) with label: 1
# Collected color: [214 209 211] at position: (362, 230) with label: 1
# Collected color: [181 179 179] at position: (433, 234) with label: 1
# Collected color: [175 171 173] at position: (471, 228) with label: 1
# Collected color: [153 152 154] at position: (477, 204) with label: 1
# Collected color: [184 170 173] at position: (460, 182) with label: 1
# Collected color: [191 184 184] at position: (421, 168) with label: 1
# Collected color: [186 176 176] at position: (406, 149) with label: 1
# Collected color: [208 204 204] at position: (381, 133) with label: 1
# Collected color: [216 207 201] at position: (361, 105) with label: 1
# Collected color: [222 213 210] at position: (357, 84) with label: 1
# Collected color: [197 186 183] at position: (358, 70) with label: 1
# Collected color: [253 243 232] at position: (369, 55) with label: 1
# Collected color: [255 254 249] at position: (386, 49) with label: 1
# Collected color: [254 249 243] at position: (396, 46) with label: 1
# Collected color: [217 213 206] at position: (373, 48) with label: 1
# Collected color: [211 202 199] at position: (358, 83) with label: 1
# Collected color: [171 163 166] at position: (378, 102) with label: 1
# Collected color: [214 201 196] at position: (395, 126) with label: 1
# Collected color: [197 189 186] at position: (407, 144) with label: 1
# Collected color: [208 199 196] at position: (445, 177) with label: 1
# Collected color: [186 178 175] at position: (471, 182) with label: 1
# Collected color: [220 217 215] at position: (339, 121) with label: 1
# Collected color: [241 225 223] at position: (326, 75) with label: 1
# Collected color: [215 210 215] at position: (280, 81) with label: 1
# Collected color: [240 227 219] at position: (334, 100) with label: 1
# Collected color: [200 204 213] at position: (261, 124) with label: 1
# Collected color: [226 223 228] at position: (179, 137) with label: 1
# Collected color: [201 201 205] at position: (91, 164) with label: 1
# Collected color: [222 222 226] at position: (133, 203) with label: 1
# Collected color: [179 176 178] at position: (374, 190) with label: 1
# Collected color: [254 254 254] at position: (305, 130) with label: 1
# Collected color: [202 200 202] at position: (162, 155) with label: 1
# Collected color: [196 195 201] at position: (315, 177) with label: 1
# Collected color: [187 188 191] at position: (380, 135) with label: 1
# Collected color: [249 236 228] at position: (348, 100) with label: 1
# Collected color: [248 236 230] at position: (355, 68) with label: 1
# Collected color: [174 176 182] at position: (304, 72) with label: 1
# Collected color: [236 228 235] at position: (208, 118) with label: 1
# Collected color: [235 241 241] at position: (119, 165) with label: 1
# Collected color: [196 197 202] at position: (53, 195) with label: 1
# Collected color: [184 184 191] at position: (108, 238) with label: 1
# Collected color: [191 188 192] at position: (320, 238) with label: 1
# Collected color: [180 182 187] at position: (431, 223) with label: 1
# Collected color: [178 180 181] at position: (389, 165) with label: 1
# Collected color: [205 206 217] at position: (229, 136) with label: 1
# Collected color: [203 202 207] at position: (89, 176) with label: 1
# Collected color: [193 189 194] at position: (33, 165) with label: 1
# Collected color: [213 208 209] at position: (95, 147) with label: 1
# Collected color: [164 169 180] at position: (273, 104) with label: 1
# Collecting positive samples. Press 'y' to switch, 'Esc' to stop.
# Collected color: [ 99 106 115] at position: (13, 134) with label: 0
# Collected color: [ 97 117 116] at position: (44, 119) with label: 0
# Collected color: [100 112 110] at position: (82, 106) with label: 0
# Collected color: [133 140 142] at position: (117, 99) with label: 0
# Collected color: [ 78 100  90] at position: (155, 84) with label: 0
# Collected color: [ 77 102  96] at position: (180, 78) with label: 0
# Collected color: [ 91 113 102] at position: (207, 68) with label: 0
# Collected color: [74 95 91] at position: (238, 59) with label: 0
# Collected color: [ 97 118 105] at position: (267, 51) with label: 0
# Collected color: [ 99 109  98] at position: (297, 44) with label: 0
# Collected color: [45 44 36] at position: (329, 39) with label: 0
# Collected color: [74 85 65] at position: (353, 36) with label: 0
# Collected color: [63 60 50] at position: (388, 33) with label: 0
# Collected color: [61 64 58] at position: (409, 32) with label: 0
# Collected color: [71 63 56] at position: (434, 32) with label: 0
# Collected color: [66 74 62] at position: (458, 32) with label: 0
# Collected color: [42 39 34] at position: (472, 38) with label: 0
# Collected color: [70 84 81] at position: (453, 53) with label: 0
# Collected color: [110 106 103] at position: (428, 54) with label: 0
# Collected color: [108 123 123] at position: (415, 58) with label: 0
# Collected color: [166 167 174] at position: (402, 65) with label: 0
# Collected color: [114 124 123] at position: (399, 71) with label: 0
# Collected color: [122 118 123] at position: (398, 67) with label: 0
# Collected color: [105 106 106] at position: (409, 59) with label: 0
# Collected color: [118 126 114] at position: (395, 61) with label: 0
# Collected color: [109 117 117] at position: (384, 70) with label: 0
# Collected color: [162 167 162] at position: (394, 88) with label: 0
# Collected color: [172 166 165] at position: (403, 102) with label: 0
# Collected color: [136 142 144] at position: (423, 115) with label: 0
# Collected color: [ 93 105 110] at position: (451, 128) with label: 0
# Collected color: [ 84  92 100] at position: (476, 140) with label: 0
# Collected color: [117 117 115] at position: (481, 117) with label: 0
# Collected color: [53 52 54] at position: (466, 79) with label: 0
# Collected color: [49 50 54] at position: (438, 83) with label: 0
# Collected color: [ 93  95 105] at position: (479, 140) with label: 0
# Collected color: [104 108 121] at position: (489, 145) with label: 0
# Collected color: [ 84  92 100] at position: (493, 130) with label: 0
# Collected color: [73 83 89] at position: (492, 153) with label: 0
# Collected color: [69 78 83] at position: (492, 154) with label: 0
# Collected color: [70 79 69] at position: (476, 86) with label: 0
# Collected color: [63 67 62] at position: (488, 55) with label: 0
# Collected color: [54 66 48] at position: (495, 21) with label: 0
# Collected color: [61 60 50] at position: (458, 14) with label: 0
# Collected color: [48 46 37] at position: (394, 21) with label: 0
# Collected color: [76 70 62] at position: (347, 24) with label: 0
# Collected color: [56 53 48] at position: (310, 18) with label: 0
# Collected color: [65 75 60] at position: (269, 22) with label: 0
# Collected color: [63 62 47] at position: (235, 23) with label: 0
# Collected color: [78 82 78] at position: (308, 43) with label: 0
# Collected color: [71 67 60] at position: (342, 27) with label: 0
# Collected color: [74 69 63] at position: (441, 17) with label: 0
# Collected color: [58 52 45] at position: (463, 12) with label: 0
# Collected color: [85 76 69] at position: (326, 15) with label: 0
# Collected color: [77 70 63] at position: (255, 12) with label: 0
# Collected color: [71 74 60] at position: (218, 27) with label: 0
# Collected color: [75 98 94] at position: (197, 70) with label: 0
# Collected color: [56 63 60] at position: (204, 27) with label: 0
# Collected color: [56 62 49] at position: (205, 24) with label: 0
# Collected color: [56 76 62] at position: (172, 69) with label: 0
# Collected color: [28 26 25] at position: (157, 40) with label: 0
# Collected color: [30 30 25] at position: (160, 37) with label: 0
# Collected color: [70 71 77] at position: (116, 62) with label: 0
# Collected color: [33 34 28] at position: (105, 19) with label: 0
# Collected color: [62 73 59] at position: (66, 26) with label: 0
# Collected color: [56 68 51] at position: (41, 27) with label: 0
# Collected color: [32 32 32] at position: (23, 35) with label: 0
# Collected color: [73 94 88] at position: (9, 104) with label: 0
# Collected color: [41 48 38] at position: (60, 82) with label: 0
# Collected color: [67 71 71] at position: (98, 55) with label: 0
# Collected color: [37 35 30] at position: (147, 54) with label: 0
# Collected color: [75 87 77] at position: (250, 47) with label: 0
# Collected color: [68 58 52] at position: (339, 15) with label: 0
# Collected color: [75 71 60] at position: (443, 12) with label: 0
# Collected color: [77 83 68] at position: (478, 39) with label: 0
# Collected color: [33 42 37] at position: (490, 87) with label: 0
# Collected color: [ 98 105 108] at position: (479, 128) with label: 0
# Stopping data collection.

# %%
features = np.array(features)
labels = np.array(labels)

# %% [markdown]
# 绘制R-G图

# %%
def Plot_BGR(features):
    # 分离正负样本
    positive_features = features[labels == 1]
    negative_features = features[labels == 0]
    
    # opencv 默认提取通道是BGR -> B(0), G(1) R(2)
    positive_R = positive_features[:, 2]
    positive_G = positive_features[:, 1]
    
    negative_R = negative_features[:, 2]
    negative_G = negative_features[:, 1]
    
    plt.scatter(positive_R, positive_G, color='red', label='Positive Samples')
    plt.scatter(negative_R, negative_G, color='blue', label='Negative Samples')
    
    plt.title('R-G channel Plot')
    plt.xlabel('R Channel')
    plt.ylabel('G Channel')
    plt.legend()
    
    plt.show()

# %%
# 未标准化训练集R-G图像
Plot_BGR(features)

# %%
# 标准化
scaler = StandardScaler()
features = scaler.fit_transform(features)

# %%
# 标准化训练集R-G图像
Plot_BGR(features)

# %% [markdown]
# svm = svm.SVC(kernel='linear')

# %% [markdown]
# svm.fit(features, labels)

# %% [markdown]
# import joblib
# joblib.dump(svm, 'svm_model.pkl')
# print('---finish---')
