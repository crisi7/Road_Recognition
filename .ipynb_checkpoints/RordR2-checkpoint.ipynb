# %%
import cv2
import numpy as np
from sklearn import svm
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
features = []
labels = []

# %%
# 用于决定采集的数据标签
is_positive = False

# %%
# 鼠标回调函数
def on_mouse(event, x, y, flags, param):
    global features, labels, is_positive

    if event == cv2.EVENT_LBUTTONDOWN:
        color = img[y, x] # 虽然是img[y, x], 但是返回的是BGR三个通道的数值

        # 根据标签决定是正样本还是负样本，标签在主函数中根据键入来更改
        if is_positive:
            labels.append(1)
        else:
            labels.append(0)

        features.append(color)
        print(f'Collected color: {color} at position: {(x, y)} with label: {labels[-1]}')

# %%
cv2.namedWindow('image')
cv2.setMouseCallback("image", on_mouse)

img = cv2.imread('./data/0618.png')

while True:
    cv2.imshow('image', img)

    key = cv2.waitKey(1) & 0xFF

    if key == ord('y'):
        print(f"Collecting positive samples. Press 'n' to switch, 'Esc' to stop.")
        is_positive = True
    elif key == ord('n'):
        print(f"Collecting positive samples. Press 'y' to switch, 'Esc' to stop.")
        is_positive = False
    elif key == 27:
        print("Stopping data collection.")
        break

cv2.destroyAllWindows()
# Out:
# Collecting positive samples. Press 'n' to switch, 'Esc' to stop.
# Collected color: [206 197 200] at position: (37, 183) with label: 1
# Collected color: [218 212 214] at position: (102, 159) with label: 1
# Collected color: [216 211 218] at position: (125, 143) with label: 1
# Collected color: [217 216 220] at position: (176, 120) with label: 1
# Collected color: [252 243 244] at position: (212, 101) with label: 1
# Collected color: [214 208 214] at position: (265, 90) with label: 1
# Collected color: [217 215 218] at position: (293, 76) with label: 1
# Collected color: [199 193 188] at position: (323, 63) with label: 1
# Collected color: [240 227 218] at position: (346, 54) with label: 1
# Collected color: [232 221 212] at position: (377, 45) with label: 1
# Collected color: [221 209 206] at position: (386, 45) with label: 1
# Collected color: [215 207 206] at position: (358, 65) with label: 1
# Collected color: [238 221 216] at position: (362, 101) with label: 1
# Collected color: [211 207 207] at position: (395, 133) with label: 1
# Collected color: [184 174 174] at position: (421, 159) with label: 1
# Collected color: [200 192 189] at position: (450, 181) with label: 1
# Collected color: [157 155 155] at position: (468, 214) with label: 1
# Collected color: [178 176 175] at position: (400, 238) with label: 1
# Collected color: [199 196 205] at position: (294, 158) with label: 1
# Collected color: [189 193 198] at position: (181, 184) with label: 1
# Collected color: [175 172 176] at position: (74, 220) with label: 1
# Collected color: [183 182 184] at position: (13, 176) with label: 1
# Collected color: [214 209 209] at position: (80, 159) with label: 1
# Collected color: [222 217 219] at position: (143, 130) with label: 1
# Collected color: [251 249 250] at position: (199, 104) with label: 1
# Collected color: [232 222 225] at position: (270, 84) with label: 1
# Collected color: [249 244 237] at position: (328, 65) with label: 1
# Collected color: [233 220 214] at position: (357, 57) with label: 1
# Collected color: [231 223 211] at position: (380, 46) with label: 1
# Collected color: [240 231 219] at position: (395, 44) with label: 1
# Collected color: [255 253 246] at position: (401, 44) with label: 1
# Collecting positive samples. Press 'y' to switch, 'Esc' to stop.
# Collected color: [137 135 135] at position: (14, 141) with label: 0
# Collected color: [105 117 120] at position: (47, 133) with label: 0
# Collected color: [ 87 110 101] at position: (100, 119) with label: 0
# Collected color: [132 137 135] at position: (145, 97) with label: 0
# Collected color: [68 87 84] at position: (196, 73) with label: 0
# Collected color: [ 90 116 102] at position: (242, 61) with label: 0
# Collected color: [73 76 71] at position: (284, 48) with label: 0
# Collected color: [66 70 63] at position: (319, 42) with label: 0
# Collected color: [70 70 61] at position: (357, 38) with label: 0
# Collected color: [75 85 75] at position: (386, 37) with label: 0
# Collected color: [64 57 51] at position: (420, 33) with label: 0
# Collected color: [66 63 58] at position: (448, 33) with label: 0
# Collected color: [52 57 45] at position: (473, 35) with label: 0
# Collected color: [67 81 66] at position: (468, 46) with label: 0
# Collected color: [77 79 74] at position: (453, 48) with label: 0
# Collected color: [81 89 82] at position: (438, 49) with label: 0
# Collected color: [116 119 114] at position: (416, 55) with label: 0
# Collected color: [238 234 237] at position: (402, 60) with label: 0
# Collected color: [ 99 111 116] at position: (391, 70) with label: 0
# Collected color: [162 167 162] at position: (394, 88) with label: 0
# Collected color: [103 110 105] at position: (411, 99) with label: 0
# Collected color: [130 134 136] at position: (436, 121) with label: 0
# Collected color: [ 96 107 106] at position: (468, 140) with label: 0
# Collected color: [83 94 93] at position: (489, 155) with label: 0
# Collected color: [33 37 34] at position: (484, 97) with label: 0
# Collected color: [71 74 75] at position: (452, 72) with label: 0
# Collected color: [41 56 44] at position: (482, 87) with label: 0
# Collected color: [61 57 52] at position: (483, 28) with label: 0
# Collected color: [93 85 71] at position: (443, 2) with label: 0
# Collected color: [57 58 48] at position: (397, 27) with label: 0
# Collected color: [42 40 33] at position: (357, 25) with label: 0
# Collected color: [62 64 53] at position: (286, 15) with label: 0
# Collected color: [43 47 39] at position: (252, 38) with label: 0
# Collected color: [46 55 45] at position: (238, 34) with label: 0
# Collected color: [76 87 72] at position: (210, 30) with label: 0
# Collected color: [44 40 35] at position: (197, 43) with label: 0
# Collected color: [48 53 50] at position: (201, 19) with label: 0
# Collected color: [38 39 32] at position: (196, 18) with label: 0
# Collected color: [84 81 74] at position: (166, 64) with label: 0
# Collected color: [59 62 53] at position: (118, 35) with label: 0
# Collected color: [38 41 30] at position: (73, 20) with label: 0
# Collected color: [22 23 19] at position: (22, 21) with label: 0
# Collected color: [42 48 41] at position: (37, 102) with label: 0
# Collected color: [47 59 51] at position: (106, 76) with label: 0
# Collected color: [46 55 46] at position: (59, 54) with label: 0
# Collected color: [52 65 51] at position: (104, 74) with label: 0
# Collected color: [45 53 42] at position: (71, 69) with label: 0
# Stopping data collection.

# %%
features = np.array(features)
labels = np.array(labels)

# %% [markdown]
# 绘制R-G图

# %%
def Plot_BGR(features):
    # 分离正负样本
    positive_features = features[labels == 1]
    negative_features = features[labels == 0]
    
    # opencv 默认提取通道是BGR -> B(0), G(1) R(2)
    positive_R = positive_features[:, 2]
    positive_G = positive_features[:, 1]
    
    negative_R = negative_features[:, 2]
    negative_G = negative_features[:, 1]
    
    plt.scatter(positive_R, positive_G, color='red', label='Positive Samples')
    plt.scatter(negative_R, negative_G, color='blue', label='Negative Samples')
    
    plt.title('R-G channel Plot')
    plt.xlabel('R Channel')
    plt.ylabel('G Channel')
    plt.legend()
    
    plt.show()

# %%
# 未标准化训练集R-G图像
Plot_BGR(features)

# %%
# 标准化
scaler = StandardScaler()
features = scaler.fit_transform(features)

# %%
# 标准化训练集R-G图像
Plot_BGR(features)

# %% [markdown]
# svm = svm.SVC(kernel='linear')

# %% [markdown]
# svm.fit(features, labels)

# %% [markdown]
# import joblib
# joblib.dump(svm, 'svm_model.pkl')
# print('---finish---')
